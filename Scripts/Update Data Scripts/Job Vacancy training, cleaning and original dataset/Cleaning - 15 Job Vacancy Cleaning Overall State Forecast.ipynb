# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. load ACT and Inspect

# %%
ACT_vac = pd.read_csv('C:/Users/yiran/Google Drive/2018 S1/Cleaning Data/Material Data/Job Vacancy Clean Final/JOB VACANCY ACT Forecast.csv')

# %%
ACT_vac.head(5)
# Out:
#                                OCCUPATIONS        Time  vacancy ACT
# 0  Chief Executives And Managing Directors  2018-03-01    11.070153
# 1  Chief Executives And Managing Directors  2018-04-01    10.922458
# 2  Chief Executives And Managing Directors  2018-05-01    11.490664
# 3  Chief Executives And Managing Directors  2018-06-01    11.906011
# 4  Chief Executives And Managing Directors  2018-07-01    11.954724

# %%
len(ACT_vac)
# Out:
# 8256

# %%
ACT_vac = ACT_vac.drop(['Unnamed: 0'], axis=1)

# %%
ACT_vac = ACT_vac.rename(columns={'Vacancy' : 'vacancy ACT'})

# %%
ACT_vac = ACT_vac[["OCCUPATIONS","Time","vacancy ACT"]]

# %% [markdown]
# ### 2. load NT and Inspect

# %%
NT_vac = pd.read_csv('C:/Users/yiran/Google Drive/2018 S1/Cleaning Data/Material Data/Job Vacancy Clean Final/JOB VACANCY NT Forecast.csv')

# %%
NT_vac.head(5)
# Out:
#                                OCCUPATIONS        Time  vacancy NT
# 0  Chief Executives And Managing Directors  2018-03-01    4.311513
# 1  Chief Executives And Managing Directors  2018-04-01    5.042963
# 2  Chief Executives And Managing Directors  2018-05-01    6.354248
# 3  Chief Executives And Managing Directors  2018-06-01    6.761318
# 4  Chief Executives And Managing Directors  2018-07-01    7.341487

# %%
len(NT_vac)
# Out:
# 8256

# %%
NT_vac = NT_vac.drop(['Unnamed: 0'], axis=1)

# %%
NT_vac = NT_vac.rename(columns={'Vacancy' : 'vacancy NT'})

# %%
NT_vac = NT_vac[["OCCUPATIONS","Time","vacancy NT"]]

# %% [markdown]
# ### 3. load QLD and Inspect

# %%
QLD_vac = pd.read_csv('C:/Users/yiran/Google Drive/2018 S1/Cleaning Data/Material Data/Job Vacancy Clean Final/JOB VACANCY QLD Forecast.csv')

# %%
QLD_vac.head(5)
# Out:
#                                OCCUPATIONS        Time  vacancy QLD
# 0  Chief Executives And Managing Directors  2018-03-01         40.0
# 1  Chief Executives And Managing Directors  2018-04-01         40.0
# 2  Chief Executives And Managing Directors  2018-05-01         40.0
# 3  Chief Executives And Managing Directors  2018-06-01         40.0
# 4  Chief Executives And Managing Directors  2018-07-01         40.0

# %%
len(QLD_vac)
# Out:
# 8256

# %%
QLD_vac = QLD_vac.drop(['Unnamed: 0'], axis=1)

# %%
QLD_vac = QLD_vac.rename(columns={'Vacancy' : 'vacancy QLD'})

# %%
QLD_vac = QLD_vac[["OCCUPATIONS","Time","vacancy QLD"]]

# %% [markdown]
# ### 4. load SA and Inspect

# %%
SA_vac = pd.read_csv('C:/Users/yiran/Google Drive/2018 S1/Cleaning Data/Material Data/Job Vacancy Clean Final/JOB VACANCY SA Forecast.csv')

# %%
SA_vac.head(5)
# Out:
#    Unnamed: 0        Time  Vacancy                              OCCUPATIONS
# 0           1  2018-03-01    14.67  Chief Executives And Managing Directors
# 1           2  2018-04-01    14.67  Chief Executives And Managing Directors
# 2           3  2018-05-01    14.67  Chief Executives And Managing Directors
# 3           4  2018-06-01    14.67  Chief Executives And Managing Directors
# 4           5  2018-07-01    14.67  Chief Executives And Managing Directors

# %%
len(SA_vac)
# Out:
# 8256

# %%
SA_vac = SA_vac.drop(['Unnamed: 0'], axis=1)

# %%
SA_vac = SA_vac.rename(columns={'Vacancy' : 'vacancy SA'})

# %%
SA_vac = SA_vac[["OCCUPATIONS","Time","vacancy SA"]]

# %%
SA_vac.head(5)
# Out:
#                                OCCUPATIONS        Time  vacancy SA
# 0  Chief Executives And Managing Directors  2018-03-01       14.67
# 1  Chief Executives And Managing Directors  2018-04-01       14.67
# 2  Chief Executives And Managing Directors  2018-05-01       14.67
# 3  Chief Executives And Managing Directors  2018-06-01       14.67
# 4  Chief Executives And Managing Directors  2018-07-01       14.67

# %% [markdown]
# ### load 5. TAS and Inspect

# %%
TAS_vac = pd.read_csv('C:/Users/yiran/Google Drive/2018 S1/Cleaning Data/Material Data/Job Vacancy Clean Final/JOB VACANCY TAS Forecast.csv')

# %%
TAS_vac.head(5)
# Out:
#    Unnamed: 0        Time   Vacancy                              OCCUPATIONS
# 0           1  2018-03-01  4.293900  Chief Executives And Managing Directors
# 1           2  2018-04-01  4.203974  Chief Executives And Managing Directors
# 2           3  2018-05-01  4.394047  Chief Executives And Managing Directors
# 3           4  2018-06-01  4.540766  Chief Executives And Managing Directors
# 4           5  2018-07-01  4.650192  Chief Executives And Managing Directors

# %%
len(TAS_vac)
# Out:
# 8256

# %%
TAS_vac = TAS_vac.drop(['Unnamed: 0'], axis=1)

# %%
TAS_vac = TAS_vac.rename(columns={'Vacancy' : 'vacancy TAS'})

# %%
TAS_vac = TAS_vac[["OCCUPATIONS","Time","vacancy TAS"]]

# %%
TAS_vac.head(5)
# Out:
#                                OCCUPATIONS        Time  vacancy TAS
# 0  Chief Executives And Managing Directors  2018-03-01     4.293900
# 1  Chief Executives And Managing Directors  2018-04-01     4.203974
# 2  Chief Executives And Managing Directors  2018-05-01     4.394047
# 3  Chief Executives And Managing Directors  2018-06-01     4.540766
# 4  Chief Executives And Managing Directors  2018-07-01     4.650192

# %% [markdown]
# ### 6. Load VIC and Inspect

# %%
VIC_vac = pd.read_csv('C:/Users/yiran/Google Drive/2018 S1/Cleaning Data/Material Data/Job Vacancy Clean Final/JOB VACANCY VIC Forecast.csv')

# %%
VIC_vac.head(5)
# Out:
#    Unnamed: 0        Time    Vacancy                              OCCUPATIONS
# 0           1  2018-03-01  78.375699  Chief Executives And Managing Directors
# 1           2  2018-04-01  73.515532  Chief Executives And Managing Directors
# 2           3  2018-05-01  78.480203  Chief Executives And Managing Directors
# 3           4  2018-06-01  80.277841  Chief Executives And Managing Directors
# 4           5  2018-07-01  81.931745  Chief Executives And Managing Directors

# %%
len(VIC_vac)
# Out:
# 8256

# %%
VIC_vac = VIC_vac.drop(['Unnamed: 0'], axis=1)

# %%
VIC_vac = VIC_vac.rename(columns={'Vacancy' : 'vacancy VIC'})

# %%
VIC_vac = VIC_vac[["OCCUPATIONS","Time","vacancy VIC"]]

# %%
VIC_vac.head(5)
# Out:
#                                OCCUPATIONS        Time  vacancy VIC
# 0  Chief Executives And Managing Directors  2018-03-01    78.375699
# 1  Chief Executives And Managing Directors  2018-04-01    73.515532
# 2  Chief Executives And Managing Directors  2018-05-01    78.480203
# 3  Chief Executives And Managing Directors  2018-06-01    80.277841
# 4  Chief Executives And Managing Directors  2018-07-01    81.931745

# %% [markdown]
# ### 7. Load WA and Inspect

# %%
WA_vac = pd.read_csv('C:/Users/yiran/Google Drive/2018 S1/Cleaning Data/Material Data/Job Vacancy Clean Final/JOB VACANCY WA Forecast.csv')

# %%
WA_vac.head(5)
# Out:
#    Unnamed: 0        Time    Vacancy                              OCCUPATIONS
# 0           1  2018-03-01  29.837529  Chief Executives And Managing Directors
# 1           2  2018-04-01  27.163937  Chief Executives And Managing Directors
# 2           3  2018-05-01  24.618406  Chief Executives And Managing Directors
# 3           4  2018-06-01  23.480377  Chief Executives And Managing Directors
# 4           5  2018-07-01  22.971600  Chief Executives And Managing Directors

# %%
len(WA_vac)
# Out:
# 8256

# %%
WA_vac = WA_vac.drop(['Unnamed: 0'], axis=1)

# %%
WA_vac = WA_vac.rename(columns={'Vacancy' : 'vacancy WA'})

# %%
WA_vac = WA_vac[["OCCUPATIONS","Time","vacancy WA"]]

# %%
WA_vac.head(5)
# Out:
#                                OCCUPATIONS        Time  vacancy WA
# 0  Chief Executives And Managing Directors  2018-03-01   29.837529
# 1  Chief Executives And Managing Directors  2018-04-01   27.163937
# 2  Chief Executives And Managing Directors  2018-05-01   24.618406
# 3  Chief Executives And Managing Directors  2018-06-01   23.480377
# 4  Chief Executives And Managing Directors  2018-07-01   22.971600

# %% [markdown]
# ### 8. Load NSW and Inspect

# %%
NSW_vac = pd.read_csv('C:/Users/yiran/Google Drive/2018 S1/Cleaning Data/Material Data/Job Vacancy Clean Final/JOB VACANCY NSW Forecast.csv')

# %%
NSW_vac.head(5)
# Out:
#    Unnamed: 0        Time     Vacancy                              OCCUPATIONS
# 0           1  2018-03-01  117.490102  Chief Executives And Managing Directors
# 1           2  2018-04-01  114.324972  Chief Executives And Managing Directors
# 2           3  2018-05-01  122.384178  Chief Executives And Managing Directors
# 3           4  2018-06-01  121.888163  Chief Executives And Managing Directors
# 4           5  2018-07-01  131.973251  Chief Executives And Managing Directors

# %%
len(NSW_vac)
# Out:
# 8256

# %%
NSW_vac = NSW_vac.drop(['Unnamed: 0'], axis=1)

# %%
NSW_vac = NSW_vac.rename(columns={'Vacancy' : 'vacancy NSW'})

# %%
NSW_vac = NSW_vac[["OCCUPATIONS","Time","vacancy NSW"]]

# %%
NSW_vac.head(5)
# Out:
#                                OCCUPATIONS        Time  vacancy NSW
# 0  Chief Executives And Managing Directors  2018-03-01   117.490102
# 1  Chief Executives And Managing Directors  2018-04-01   114.324972
# 2  Chief Executives And Managing Directors  2018-05-01   122.384178
# 3  Chief Executives And Managing Directors  2018-06-01   121.888163
# 4  Chief Executives And Managing Directors  2018-07-01   131.973251

# %% [markdown]
# ### 9. Load AUST and Inspect

# %%
AUST_vac = pd.read_csv('C:/Users/yiran/Google Drive/2018 S1/Cleaning Data/Material Data/Job Vacancy Clean Final/JOB VACANCY AUST Forecast.csv')

# %%
AUST_vac.head(5)
# Out:
#                                OCCUPATIONS      Time     Vacancy
# 0  Chief Executives And Managing Directors  01-03-18  311.497514
# 1  Chief Executives And Managing Directors  01-04-18  279.831631
# 2  Chief Executives And Managing Directors  01-05-18  300.239952
# 3  Chief Executives And Managing Directors  01-06-18  301.577864
# 4  Chief Executives And Managing Directors  01-07-18  314.110879

# %%
len(AUST_vac)
# Out:
# 8256

# %%
AUST_vac = AUST_vac.rename(columns={'Vacancy' : 'vacancy AUST'})

# %%
AUST_vac = AUST_vac[["OCCUPATIONS","Time","vacancy AUST"]]

# %%
AUST_vac.head(5)
# Out:
#                                OCCUPATIONS      Time  vacancy AUST
# 0  Chief Executives And Managing Directors  01-03-18    311.497514
# 1  Chief Executives And Managing Directors  01-04-18    279.831631
# 2  Chief Executives And Managing Directors  01-05-18    300.239952
# 3  Chief Executives And Managing Directors  01-06-18    301.577864
# 4  Chief Executives And Managing Directors  01-07-18    314.110879

# %% [markdown]
# ### Reformat AUST Time Format

# %%
reformat = pd.DataFrame(AUST_vac.Time.str.split('-').tolist(),
                                   columns = ['Day','Month', 'Year'])

# %%
reformat.head(5)
# Out:
#   Day Month Year
# 0  01    03   18
# 1  01    04   18
# 2  01    05   18
# 3  01    06   18
# 4  01    07   18

# %%
ly = len(reformat.Year)
x = np.array(["20"])
print np.repeat(x, [ly], axis=0)
# Out:
# ['20' '20' '20' ..., '20' '20' '20']

# %%
y_20 = pd.DataFrame(np.repeat(x, [ly], axis=0))

# %%
y_20 = y_20.rename(columns={0 : 'yn'})

# %%
len(y_20)
# Out:
# 8256

# %%
y_20.head(5)
# Out:
#    yn
# 0  20
# 1  20
# 2  20
# 3  20
# 4  20

# %%
reformat.Year = y_20.yn+reformat.Year

# %%
reformat.head(5)
# Out:
#   Day Month  Year
# 0  01    03  2018
# 1  01    04  2018
# 2  01    05  2018
# 3  01    06  2018
# 4  01    07  2018

# %%
reformat_time = reformat.Year+'-'+reformat.Month+'-'+reformat.Day

# %%
reformat_time = pd.DataFrame(reformat_time)

# %%
AUST_vac.Time = reformat_time

# %%
AUST_vac.head(5)
# Out:
#                                OCCUPATIONS        Time  vacancy AUST
# 0  Chief Executives And Managing Directors  2018-03-01    311.497514
# 1  Chief Executives And Managing Directors  2018-04-01    279.831631
# 2  Chief Executives And Managing Directors  2018-05-01    300.239952
# 3  Chief Executives And Managing Directors  2018-06-01    301.577864
# 4  Chief Executives And Managing Directors  2018-07-01    314.110879

# %%
AUST_vac.tail(5)
# Out:
#                         OCCUPATIONS        Time  vacancy AUST
# 8251  Other Miscellaneous Labourers  2019-10-01   4237.218105
# 8252  Other Miscellaneous Labourers  2019-11-01   4254.227338
# 8253  Other Miscellaneous Labourers  2019-12-01   3658.493456
# 8254  Other Miscellaneous Labourers  2020-01-01   3367.828425
# 8255  Other Miscellaneous Labourers  2020-02-01   3328.896278

# %% [markdown]
# ## Horizontal Join them

# %% [markdown]
# ### Join ACT and NT

# %%
act_nt_joined = pd.merge(ACT_vac, NT_vac, on=['OCCUPATIONS', 'Time'])

# %%
len(act_nt_joined)
# Out:
# 8256

# %% [markdown]
# ### Add QLD

# %%
act_nt_QLD_joined = pd.merge(act_nt_joined, QLD_vac, on=['OCCUPATIONS', 'Time'])

# %%
len(act_nt_QLD_joined)
# Out:
# 8256

# %% [markdown]
# ###  Add SA

# %%
act_nt_QLD_SA_joined = pd.merge(act_nt_QLD_joined, SA_vac, on=['OCCUPATIONS', 'Time'])

# %%
len(act_nt_QLD_SA_joined)
# Out:
# 8256

# %% [markdown]
# ### Add TAS

# %%
act_nt_QLD_SA_TAS_joined = pd.merge(act_nt_QLD_SA_joined, TAS_vac, on=['OCCUPATIONS', 'Time'])

# %%
len(act_nt_QLD_SA_TAS_joined)
# Out:
# 8256

# %% [markdown]
# ### Add VIC

# %%
act_nt_QLD_SA_TAS_VIC_joined = pd.merge(act_nt_QLD_SA_TAS_joined, VIC_vac, on=['OCCUPATIONS', 'Time'])

# %%
len(act_nt_QLD_SA_TAS_VIC_joined)
# Out:
# 8256

# %% [markdown]
# ### Add WA

# %%
act_nt_QLD_SA_TAS_VIC_WA_joined = pd.merge(act_nt_QLD_SA_TAS_VIC_joined, WA_vac, on=['OCCUPATIONS', 'Time'])

# %%
len(act_nt_QLD_SA_TAS_VIC_WA_joined)
# Out:
# 8256

# %% [markdown]
# ### Add NSW

# %%
act_nt_QLD_SA_TAS_VIC_WA_NSW_joined = pd.merge(act_nt_QLD_SA_TAS_VIC_WA_joined, NSW_vac, on=['OCCUPATIONS', 'Time'])

# %%
len(act_nt_QLD_SA_TAS_VIC_WA_NSW_joined)
# Out:
# 8256

# %% [markdown]
# ### Add AUST

# %%
act_nt_QLD_SA_TAS_VIC_WA_NSW_AUST_joined = pd.merge(act_nt_QLD_SA_TAS_VIC_WA_NSW_joined, AUST_vac, on=['OCCUPATIONS', 'Time'])

# %%
len(act_nt_QLD_SA_TAS_VIC_WA_NSW_AUST_joined)
# Out:
# 8256

# %% [markdown]
# # Inspect each dataframe

# %%
act_nt_QLD_SA_TAS_VIC_WA_NSW_AUST_joined.head(5)
# Out:
#                                OCCUPATIONS        Time  vacancy ACT  \
# 0  Chief Executives And Managing Directors  2018-03-01    11.070153
# 1  Chief Executives And Managing Directors  2018-04-01    10.922458
# 2  Chief Executives And Managing Directors  2018-05-01    11.490664
# 3  Chief Executives And Managing Directors  2018-06-01    11.906011
# 4  Chief Executives And Managing Directors  2018-07-01    11.954724
#
#    vacancy NT  vacancy QLD  vacancy SA  vacancy TAS  vacancy VIC  vacancy WA  \
# 0    4.311513         40.0       14.67     4.293900    78.375699   29.837529
# 1    5.042963         40.0       14.67     4.203974    73.515532   27.163937
# 2    6.354248         40.0       14.67     4.394047    78.480203   24.618406
# 3    6.761318         40.0       14.67     4.540766    80.277841   23.480377
# 4    7.341487         40.0       14.67     4.650192    81.931745   22.971600
#
#    vacancy NSW  vacancy AUST
# 0   117.490102    311.497514
# 1   114.324972    279.831631
# ...

# %%
act_nt_QLD_SA_TAS_VIC_WA_NSW_AUST_joined.tail(5)
# Out:
#                         OCCUPATIONS        Time  vacancy ACT  vacancy NT  \
# 8251  Other Miscellaneous Labourers  2019-10-01   122.503168   25.538427
# 8252  Other Miscellaneous Labourers  2019-11-01   121.380735   26.226151
# 8253  Other Miscellaneous Labourers  2019-12-01   115.678836   21.645407
# 8254  Other Miscellaneous Labourers  2020-01-01   115.449916   21.751935
# 8255  Other Miscellaneous Labourers  2020-02-01   117.125446   16.765195
#
#       vacancy QLD  vacancy SA  vacancy TAS  vacancy VIC  vacancy WA  \
# 8251  1161.140593  195.970022    14.120215   941.432379  353.084504
# 8252  1142.615540  199.450738    15.369729   932.540855  366.298929
# 8253  1082.095255  179.031125    13.228157   799.838300  350.119880
# 8254  1063.988283  171.613040    13.455343   734.483590  338.438068
# 8255  1064.210612  168.106952    12.753790   753.710008  331.360100
#
#       vacancy NSW  vacancy AUST
# 8251  1360.409823   4237.218105
# 8252  1353.602822   4254.227338
# ...

# %% [markdown]
# ## Reformat Final Dataframe

# %%
state_all = act_nt_QLD_SA_TAS_VIC_WA_NSW_AUST_joined.copy()

# %%
state_all
# Out:
#                                   OCCUPATIONS        Time  vacancy ACT  \
# 0     Chief Executives And Managing Directors  2018-03-01    11.070153
# 1     Chief Executives And Managing Directors  2018-04-01    10.922458
# 2     Chief Executives And Managing Directors  2018-05-01    11.490664
# 3     Chief Executives And Managing Directors  2018-06-01    11.906011
# 4     Chief Executives And Managing Directors  2018-07-01    11.954724
# 5     Chief Executives And Managing Directors  2018-08-01    12.346975
# 6     Chief Executives And Managing Directors  2018-09-01    12.107745
# 7     Chief Executives And Managing Directors  2018-10-01    11.832312
# 8     Chief Executives And Managing Directors  2018-11-01    12.012740
# 9     Chief Executives And Managing Directors  2018-12-01    11.639620
# 10    Chief Executives And Managing Directors  2019-01-01    11.564953
# 11    Chief Executives And Managing Directors  2019-02-01    10.909864
# ...

# %%
state_all = state_all.rename(columns={'OCCUPATIONS': 'occname', 'Time' : 'time'})

# %%
state_all.head(5)
# Out:
#                                    occname        time  vacancy ACT  \
# 0  Chief Executives And Managing Directors  2018-03-01    11.070153
# 1  Chief Executives And Managing Directors  2018-04-01    10.922458
# 2  Chief Executives And Managing Directors  2018-05-01    11.490664
# 3  Chief Executives And Managing Directors  2018-06-01    11.906011
# 4  Chief Executives And Managing Directors  2018-07-01    11.954724
#
#    vacancy NT  vacancy QLD  vacancy SA  vacancy TAS  vacancy VIC  vacancy WA  \
# 0    4.311513         40.0       14.67     4.293900    78.375699   29.837529
# 1    5.042963         40.0       14.67     4.203974    73.515532   27.163937
# 2    6.354248         40.0       14.67     4.394047    78.480203   24.618406
# 3    6.761318         40.0       14.67     4.540766    80.277841   23.480377
# 4    7.341487         40.0       14.67     4.650192    81.931745   22.971600
#
#    vacancy NSW  vacancy AUST
# 0   117.490102    311.497514
# 1   114.324972    279.831631
# ...

# %%
reformat_state_time = pd.DataFrame(state_all.time.str.split('-').tolist(),
                                   columns = ['year','month','day'])

# %%
reformat_state_time.head(5)
# Out:
#    year month day
# 0  2018    03  01
# 1  2018    04  01
# 2  2018    05  01
# 3  2018    06  01
# 4  2018    07  01

# %%
state_all['year'] = reformat_state_time.year
state_all['month'] = reformat_state_time.month
state_all['day'] = reformat_state_time.day

# %%
state_all = state_all.drop(['time'], axis=1)

# %%
state_all
# Out:
#                                       occname  vacancy ACT  vacancy NT  \
# 0     Chief Executives And Managing Directors    11.070153    4.311513
# 1     Chief Executives And Managing Directors    10.922458    5.042963
# 2     Chief Executives And Managing Directors    11.490664    6.354248
# 3     Chief Executives And Managing Directors    11.906011    6.761318
# 4     Chief Executives And Managing Directors    11.954724    7.341487
# 5     Chief Executives And Managing Directors    12.346975    7.622779
# 6     Chief Executives And Managing Directors    12.107745    8.525380
# 7     Chief Executives And Managing Directors    11.832312    9.263563
# 8     Chief Executives And Managing Directors    12.012740    9.680709
# 9     Chief Executives And Managing Directors    11.639620    9.789086
# 10    Chief Executives And Managing Directors    11.564953    9.944168
# 11    Chief Executives And Managing Directors    10.909864   10.311997
# ...

# %%
state_all = state_all[["occname","year","month","day", "vacancy ACT", "vacancy NT", "vacancy QLD", "vacancy SA",
                       "vacancy TAS","vacancy VIC","vacancy WA","vacancy NSW","vacancy AUST"]]

# %%
state_all.head(10)
# Out:
#                                    occname  year month day  vacancy ACT  \
# 0  Chief Executives And Managing Directors  2018    03  01    11.070153
# 1  Chief Executives And Managing Directors  2018    04  01    10.922458
# 2  Chief Executives And Managing Directors  2018    05  01    11.490664
# 3  Chief Executives And Managing Directors  2018    06  01    11.906011
# 4  Chief Executives And Managing Directors  2018    07  01    11.954724
# 5  Chief Executives And Managing Directors  2018    08  01    12.346975
# 6  Chief Executives And Managing Directors  2018    09  01    12.107745
# 7  Chief Executives And Managing Directors  2018    10  01    11.832312
# 8  Chief Executives And Managing Directors  2018    11  01    12.012740
# 9  Chief Executives And Managing Directors  2018    12  01    11.639620
#
#    vacancy NT  vacancy QLD  vacancy SA  vacancy TAS  vacancy VIC  vacancy WA  \
# 0    4.311513         40.0       14.67     4.293900    78.375699   29.837529
# ...

# %%
state_all.tail(10)
# Out:
#                             occname  year month day  vacancy ACT  vacancy NT  \
# 8246  Other Miscellaneous Labourers  2019    05  01   106.537687   21.732572
# 8247  Other Miscellaneous Labourers  2019    06  01   109.094610   18.838567
# 8248  Other Miscellaneous Labourers  2019    07  01   109.978585   20.343388
# 8249  Other Miscellaneous Labourers  2019    08  01   113.844682   22.670521
# 8250  Other Miscellaneous Labourers  2019    09  01   116.745833   27.164595
# 8251  Other Miscellaneous Labourers  2019    10  01   122.503168   25.538427
# 8252  Other Miscellaneous Labourers  2019    11  01   121.380735   26.226151
# 8253  Other Miscellaneous Labourers  2019    12  01   115.678836   21.645407
# 8254  Other Miscellaneous Labourers  2020    01  01   115.449916   21.751935
# 8255  Other Miscellaneous Labourers  2020    02  01   117.125446   16.765195
#
#       vacancy QLD  vacancy SA  vacancy TAS  vacancy VIC  vacancy WA  \
# ...

# %%
state_all_final = state_all.copy()

# %%
state_all_final.to_csv("C:/Users/yiran/Google Drive/2018 S1/Cleaning Data/Material Data/VACANCY ALL STATE FORECAST.csv", index = False)
